# %%
import tensorflow as tf
import numpy as np

x = np.array([1,2,3,4],dtype=float)
y = np.array([2,4,6,8],dtype=float)

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
    
])

model.compile(optimizer='sgd',loss='mean_squared_error')

model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step - loss: 3.2158
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 2.2334
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.5517
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - loss: 1.0787
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.7504
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.5226
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.3646
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2549
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.1788
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - loss: 0.1260

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1,2,3,4],dtype=float)
y = np.array([2,4,6,8],dtype=float)

model = Sequential([
    Dense(1,input_shape=(1,))
])

model.compile(optimizer ='sgd',loss='mse')
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - loss: 69.2861
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 48.1192
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 33.4317
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 23.2401
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 16.1681
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 11.2607
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 7.8553
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 5.4922
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 3.8522
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 2.7140

# %%
import torch 
import torch.nn as nn
import torch.optim as optim

model = nn.Linear(1,)
criterion=nn.MSELoss()
optimizer = optim.SGD(model.parameter(),lr=0.01)

x=torch.tensor([1.],[2.],[3.],[4.])
y=torch.tensor([2.],[4.],[6.],[8.])

for epoch in range(10):
    optimizer.zero_grad()
    output= model(x)
    loss=criterion(output,y)
    loss.backward()
    print(f'Epoch (epoch+1), Loss: {loss.item()}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 import torch.nn as nn
#       3 import torch.optim as optim
# ----> 5 model = nn.Linear(1,)
#       6 criterion=nn.MSELoss()
#       7 optimizer = optim.SGD(model.parameter(),lr=0.01)
#
# TypeError: Linear.__init__() missing 1 required positional argument: 'out_features'
